# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x:float) -> float:
    k = np.sqrt(2)
    pi = np.pi
    return 8*(k - 1)*np.arctan(x) - pi*(k-1) - 2*x*(2*k - 1) + 7 - 4*k + x*x

def df(x:float) -> float:
    k = np.sqrt(2)
    pi = np.pi
    return 8*(k-1)/(1 + x**2) - 2*(2*k - 1) + 2*x

def d2f(x:float) -> float:
    k = np.sqrt(2)
    pi = np.pi
    return 8*(k-1)*(-2*x)/(1 + x**2)**2 + 2

def d3f(x:float) -> float:
    k = np.sqrt(2)
    pi = np.pi
    return 8*(k-1)*(2*x*2*(1 + x*x)*2*x - 2 * (1 + x*x)*(1 + x*x))/((1 + x*x)*(1 + x*x)*(1 + x*x)*(1 + x*x))

# %%
x_data = np.linspace(0.3, 0.5, 1000)
x_data2 = np.linspace(1, 1.4, 1000)
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
axs[0].plot(x_data, f(x_data), label="$f(x)$", color="blue")
axs[0].plot(x_data, df(x_data), label="$f'(x)$", color="green")
axs[0].plot(x_data, d2f(x_data), label="$f''(x)$", color="red")
axs[0].plot(x_data, d3f(x_data), label="$f'''(x)$", color="orange")
axs[0].legend()
ax = plt.gca()
# plot X - axis    
ax.axhline(y=0, color='k')
axs[0].set(ylim=(-0.0002, 0.0006))
axs[0].grid(True)

axs[1].plot(x_data2, f(x_data2), label="$f(x)$", color="blue")
axs[1].plot(x_data2, df(x_data2), label="$f'(x)$", color="green")
axs[1].legend()
axs[1].grid(True)
#fig.savefig("2.3_plot_d.png", dpi=500)

# %%
def Newton_method(root_loc:list, f, df, eps:float, m=1) -> list:
    x = [(root_loc[0] + root_loc[1])/2]
    x.append(x[-1] - m*f(x[-1])/df(x[-1]))
    while np.abs(x[-1] - x[-2]) > eps:
        x.append(x[-1] - m*f(x[-1])/df(x[-1]))
    return x

# %%
def Neat_Newton(root_loc:list, f, df, eps:float) -> list:
    x = [(root_loc[0] + root_loc[1])/2]
    k = df(x[0])
    x.append(x[-1] - f(x[-1])/k)
    while np.abs(x[-1] - x[-2]) > eps:
        x.append(x[-1] - f(x[-1])/k)
    return x

# %%
def Secant_method(root_loc:list, f, df, eps:float) -> list:
    x = [(root_loc[0] + root_loc[1])/2]
    x.append(x[-1] + 1e3*eps)
    while f(x[-1]) - f(x[-2]) != 0.0 and np.abs(x[-1] - x[-2]) > eps:
        x.append(x[-1] - (f(x[-1])*(x[-1] - x[-2]))/(f(x[-1]) - f(x[-2])))
    return x

# %%
def Chord_method(root_loc:list, f, df, eps:float) -> list:
    x = [(root_loc[0] + root_loc[1])/2]
    x.append(x[-1] + 1e3*eps)
    c = (root_loc[1] + root_loc[0])/2
    while f(x[-1]) - f(c) != 0.0 and np.abs(x[-1] - x[-2]) > eps:
        x.append(x[-1] - (f(x[-1])*(x[-1] - c))/(f(x[-1]) - f(c)))
    return x

# %%
def Steffensen_method(root_loc:list, f, df, eps:float) -> list:
    x = [root_loc[0]]
    tmp = f(x[-1])
    x.append(x[-1] - tmp**2 / (f(x[-1] + tmp) - tmp))
    while f(x[-1] + f(x[-1])) - f(x[-1]) != 0.0 and np.abs(x[-1] - x[-2]) > eps:
        tmp = f(x[-1])
        x.append(x[-1] - tmp**2 / (f(x[-1] + tmp) - tmp))
    return x

# %%
def bisection(root_loc:list, f, df, eps:float) -> list:
    x = []
    left = root_loc[0]
    right = root_loc[1]
    while np.abs(left - right) > 2*eps:
        mid = (left + right) / 2
        x.append(mid)
        if f(mid) * f(left) > 0:
            left = mid
        else:
            right = mid
    x.append((left + right) / 2)
    return x

# %%
d = [[0.4, 0.425], [1.2, 1.3]]
functions = [bisection,
        Newton_method,
        Secant_method,
        Steffensen_method,
        Chord_method,
        Neat_Newton,]

# %%
#метод простой итерации для решения уравнения f''(x) = 0
#можно использовать, так как f'''(x) монотонно возрастает на отрезке локализации

M, m = d3f(d[0][1]), d3f(d[0][0])
alpha = 2 / (M + m)
q = np.abs((M - m)/(m + M))

def phi(x): return x - alpha*d2f(x)

def Fixed_point_iter(alpha, d, q):
    x = [(d[0] + d[1])/2]
    eps = 1e-12
    x.append(phi(x[-1]))
    while np.abs(x[-1] - x[-2]) > (1 - q)/q * eps:
        x.append(phi(x[-1]))
    return x

# %%
def show_res(res, string: str):
    print("| {func_name} : {root:.12f} : {iterations:^10} |".format(func_name=string, root=res[-1], iterations=len(res)))

# %%
def show_difference(root_loc, f, df, eps):
    print("---------------------------------------------------")
    print("|       method      :      root      : iterations |")
    print("---------------------------------------------------")
    for func in functions:
        show_res(func(root_loc, f, df, eps), "{:^17}".format(func.__name__))
    print("---------------------------------------------------")

# %%
#Второй отрезок локализации(корень кратности 1) Решение уравнения f(x) = 0
show_difference(d[1], f, df, 1e-12)
# Out:
# ---------------------------------------------------
# |       method      :      root      : iterations |
# ---------------------------------------------------
# |     bisection     : 1.230215553300 :     37     |
# |   Newton_method   : 1.230215553299 :     6      |
# |   Secant_method   : 1.230215553299 :     8      |
# | Steffensen_method : 1.230215553299 :     6      |
# |   Chord_method    : 1.230215553299 :     12     |
# |    Neat_Newton    : 1.230215553299 :     13     |
# ---------------------------------------------------

# %%
#Первый отрезок локализации(корень кратности 3) Решение уравнения f(x) = 0
show_difference(d[0], f, df, 1e-12)
# Out:
# ---------------------------------------------------
# |       method      :      root      : iterations |
# ---------------------------------------------------
# |     bisection     : 0.414202547132 :     35     |
# |   Newton_method   : 0.414200921584 :     21     |
# |   Secant_method   : 0.414203082835 :     23     |
# | Steffensen_method : 0.413581653574 :     12     |
# |   Chord_method    : 0.414198800334 :    8461    |
# |    Neat_Newton    : 0.414198531775 :   24215    |
# ---------------------------------------------------

# %%
#Первый отрезок локализации(корень кратности 1) Решение уравнения f''(x) = 0
show_difference(d[0], d2f, d3f, 1e-12)
show_res(Fixed_point_iter(alpha, d[0], q), "{:^17}".format(Fixed_point_iter.__name__))
# Out:
# ---------------------------------------------------
# |       method      :      root      : iterations |
# ---------------------------------------------------
# |     bisection     : 0.414213562373 :     35     |
# |   Newton_method   : 0.414213562373 :     5      |
# |   Secant_method   : 0.414213562373 :     7      |
# | Steffensen_method : 0.414213562373 :     6      |
# |   Chord_method    : 0.414213562373 :     8      |
# |    Neat_Newton    : 0.414213562373 :     7      |
# ---------------------------------------------------
# | Fixed_point_iter  : 0.414213562373 :     7      |

# %%
def _DEBUG_bisection(root_loc:list, f, df, eps:float) -> list:
    x = []
    left = root_loc[0]
    right = root_loc[1]
    res = []
    while np.abs(left - right) > 2*eps:
        mid = (left + right) / 2
        x.append(mid)
        res.append(([left, right], f(mid)))
        if f(mid) * f(left) > 0:
            left = mid
        else:
            right = mid
    x.append((left + right) / 2)
    res.append(([left, right], f((left + right) / 2)))
    return x, res

# %%
def get_str(f, df, eps):
    print("     [{0:^20} - {1:^20}], {2:^22}".format("left", "right", "mid_value"))
    i = 0
    for it in _DEBUG_bisection(d[0], f, df, eps)[1]:
        i += 1
        left = "{0:^20.16f}".format(it[0][0])
        right = "{0:^20.16f}".format(it[0][1])
        print("{2:^2} : [{0} - {1}], {mid_value:^+22.17f}".format(left, right, i, mid_value=it[1]))

# %%
get_str(f, df, 1e-12)
# Out:
#      [        left         -        right        ],       mid_value
# 1  : [ 0.4000000000000000  -  0.4250000000000000 ],  +0.00000000168238154
# 2  : [ 0.4125000000000000  -  0.4250000000000000 ],  -0.00000003086357522
# 3  : [ 0.4125000000000000  -  0.4187500000000000 ],  -0.00000000093487387
# 4  : [ 0.4125000000000000  -  0.4156250000000000 ],  +0.00000000000114841
# 5  : [ 0.4140625000000000  -  0.4156250000000000 ],  -0.00000000008332898
# 6  : [ 0.4140625000000000  -  0.4148437500000000 ],  -0.00000000000458156
# 7  : [ 0.4140625000000000  -  0.4144531250000000 ],  -0.00000000000002989
# 8  : [ 0.4140625000000000  -  0.4142578125000000 ],  +0.00000000000005015
# 9  : [ 0.4141601562500000  -  0.4142578125000000 ],  -0.00000000000000105
# 10 : [ 0.4141601562500000  -  0.4142089843750000 ],  +0.00000000000000799
# 11 : [ 0.4141845703125000  -  0.4142089843750000 ],  +0.00000000000000067
# 12 : [ 0.4141967773437500  -  0.4142089843750000 ],  -0.00000000000000025
# ...

# %%
get_str(d2f, d3f, 1e-12)
# Out:
#      [        left         -        right        ],       mid_value
# 1  : [ 0.4000000000000000  -  0.4250000000000000 ],  +0.00344840839885063
# 2  : [ 0.4125000000000000  -  0.4250000000000000 ],  -0.00892414882650616
# 3  : [ 0.4125000000000000  -  0.4187500000000000 ],  -0.00280845641140015
# 4  : [ 0.4125000000000000  -  0.4156250000000000 ],  +0.00030229003386117
# 5  : [ 0.4140625000000000  -  0.4156250000000000 ],  -0.00125749979285938
# 6  : [ 0.4140625000000000  -  0.4148437500000000 ],  -0.00047870964379948
# 7  : [ 0.4140625000000000  -  0.4144531250000000 ],  -0.00008848607248213
# 8  : [ 0.4140625000000000  -  0.4142578125000000 ],  +0.00010683290427083
# 9  : [ 0.4141601562500000  -  0.4142578125000000 ],  +0.00000915614798158
# 10 : [ 0.4142089843750000  -  0.4142578125000000 ],  -0.00003966927907895
# 11 : [ 0.4142089843750000  -  0.4142333984375000 ],  -0.00001525764477472
# 12 : [ 0.4142089843750000  -  0.4142211914062500 ],  -0.00000305101820564
# ...

# %%
res1, res2 = _DEBUG_bisection(d[0], f, df, 1e-12)[1], _DEBUG_bisection(d[0], d2f, d3f, 1e-12)[1]

# %%
for i in range(len(res1)):
    if res1[i][0] != res2[i][0]:
        print(i)
        break
# Out:
# 9
